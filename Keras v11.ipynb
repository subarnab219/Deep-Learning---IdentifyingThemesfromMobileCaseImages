# %%
import numpy as np
np.random.seed(2016)

import os
import glob
import cv2
import datetime
import pandas as pd
import time
import warnings
# %matplotlib inline 
warnings.filterwarnings("ignore")

from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
from keras.models import Sequential
# Out:
# Using Theano backend.
# C:\Users\sran12\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def get_im_cv2(path):
    img = cv2.imread(path)
    height, width, channels = img.shape
    img = cv2.resize(img, (64, 64))
    return img

# %%
def load_train():
    X_train = []
    X_train_id = []
    y_train = []
    start_time = time.time()

    print('Read train images')
    folders = ['Automobile',
               'Comics_and_Cartoons',
               'Famous_Personalities',
               'Festivals_and_Occasions',
               'Graffiti_and_Illustrations',
               'Movies_and_TV_shows',
               'Music',
               'Nature',
               'No_Theme',
               'Patterns_and_Ethnic',
               'Signs_and_Symbols',
               'Spiritual',
               'Sports',
               'Superheroes',
               'Typography',
               'Vintage'
              ]
    for fld in folders:
        index = folders.index(fld)
        print('Load folder {} (Index: {})'.format(fld, index))
        path = os.path.join('D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train', fld, '*.jpg')
        files = glob.glob(path)
        for i in range(len(files)):
            flbase = os.path.basename(files[i])
            img = get_im_cv2(files[i])
            X_train.append(img)
            X_train_id.append(flbase)
            y_train.append(index) 
    print len(X_train)
    print('Read train data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return X_train, y_train, X_train_id

# %%
def load_test():
    path = os.path.join('D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Test', '*.jpg')
    files = sorted(glob.glob(path))

    X_test = []
    X_test_id = []
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl)
        X_test.append(img)
        X_test_id.append(flbase)

    return X_test, X_test_id

# %%
Xtrall, Ytrall, Itrall = load_train()
X_test, X_test_id = load_test()
# Out:
# Read train images
# Load folder Automobile (Index: 0)
# Load folder Comics_and_Cartoons (Index: 1)
# Load folder Famous_Personalities (Index: 2)
# Load folder Festivals_and_Occasions (Index: 3)
# Load folder Graffiti_and_Illustrations (Index: 4)
# Load folder Movies_and_TV_shows (Index: 5)
# Load folder Music (Index: 6)
# Load folder Nature (Index: 7)
# Load folder No_Theme (Index: 8)
# Load folder Patterns_and_Ethnic (Index: 9)
# Load folder Signs_and_Symbols (Index: 10)
# Load folder Spiritual (Index: 11)
# Load folder Sports (Index: 12)
# Load folder Superheroes (Index: 13)
# Load folder Typography (Index: 14)
# Load folder Vintage (Index: 15)
# 4591
# Read train data time: 279.98 seconds

# %%
# flatten out all images to be one-dimensional
Xtrall = np.array(Xtrall, dtype=np.uint8)
Ytrall = np.array(Ytrall, dtype=np.uint8)

Xtrall = Xtrall.astype('float32')
Xtrall = Xtrall / 255
Xtrall = Xtrall.transpose((0, 3, 1, 2))

X_test = np.array(X_test, dtype=np.uint8)

X_test = X_test.astype('float32')
X_test = X_test / 255
X_test = X_test.transpose((0, 3, 1, 2))

Ytrall = np_utils.to_categorical(Ytrall, 16)

# %%
batch_size=32
nb_classes=len(Ytrall)
nb_epoch=35
nb_filters=32
nb_pool=1
nb_conv=3

# %%
model= Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=Xtrall.shape[1:]))
model.add(Convolution2D(nb_filters,nb_conv,nb_conv, subsample=(1, 1),activation='relu'))
model.add(Activation('relu'))
model.add(Convolution2D(nb_filters,nb_conv,nb_conv, subsample=(1, 1),activation='relu'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(nb_pool,nb_pool)))
model.add(Flatten());
model.add(Dense(32));
model.add(Dropout(0.6));
model.add(Dense(16));
model.add(Activation('softmax'));
model.compile(loss='categorical_crossentropy',optimizer='adadelta',metrics=['accuracy'])

# %%
nfolds = 20
yfull_train = dict()
kf = KFold(len(Itrall), n_folds=nfolds, shuffle=True, random_state=51)
num_fold = 0
sum_score = 0
models = []

for mtr,mval in kf:
    Xtr = Xtrall[mtr]
    Ytr = Ytrall[mtr]
    Xval = Xtrall[mval]
    Yval = Ytrall[mval]
    
    num_fold += 1
    
    print('Start KFold number {} from {}'.format(num_fold, nfolds))
    print('Split train: ', len(Xtr), len(Ytr))
    print('Split valid: ', len(Xval), len(Yval))
    
    callbacks = [
            EarlyStopping(monitor='val_loss', patience=3, verbose=0),
        ]
    model.fit(Xtr,Ytr, batch_size=batch_size, nb_epoch=nb_epoch,
              shuffle=True, verbose=2, validation_data=(Xval, Yval),
              callbacks=callbacks)

    predictions_valid = model.predict(Xval.astype('float32'), batch_size=batch_size, verbose=2)
    score = log_loss(Yval, predictions_valid)
    print('Score log_loss: ', score)
    sum_score += score*len(mval)
    
    # Store valid predictions
    for i in range(len(mval)):
        yfull_train[mval[i]] = predictions_valid[i]

    models.append(model)
# Out:
# Start KFold number 1 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 64s - loss: 2.2309 - acc: 0.4075 - val_loss: 1.6182 - val_acc: 0.5522
# Epoch 2/35
# 58s - loss: 1.6836 - acc: 0.5361 - val_loss: 1.4552 - val_acc: 0.5870
# Epoch 3/35
# 58s - loss: 1.4412 - acc: 0.5950 - val_loss: 1.3884 - val_acc: 0.5957
# Epoch 4/35
# 57s - loss: 1.2257 - acc: 0.6563 - val_loss: 1.3409 - val_acc: 0.6174
# Epoch 5/35
# 57s - loss: 1.0771 - acc: 0.6966 - val_loss: 1.3362 - val_acc: 0.6391
# Epoch 6/35
# 57s - loss: 0.9143 - acc: 0.7450 - val_loss: 1.3283 - val_acc: 0.6087
# Epoch 7/35
# 60s - loss: 0.8071 - acc: 0.7698 - val_loss: 1.3761 - val_acc: 0.6435
# Epoch 8/35
# 58s - loss: 0.6910 - acc: 0.8065 - val_loss: 1.3245 - val_acc: 0.6348
# Epoch 9/35
# 58s - loss: 0.6415 - acc: 0.8207 - val_loss: 1.3458 - val_acc: 0.6217
# Epoch 10/35
# 57s - loss: 0.5586 - acc: 0.8422 - val_loss: 1.4052 - val_acc: 0.6217
# Epoch 11/35
# 57s - loss: 0.5167 - acc: 0.8608 - val_loss: 1.5087 - val_acc: 0.6391
# Epoch 12/35
# 57s - loss: 0.4719 - acc: 0.8659 - val_loss: 1.3907 - val_acc: 0.6565
# ('Score log_loss: ', 1.3906599407528604)
# Start KFold number 2 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 69s - loss: 0.5104 - acc: 0.8633 - val_loss: 0.2887 - val_acc: 0.9304
# Epoch 2/35
# 57s - loss: 0.4529 - acc: 0.8755 - val_loss: 0.2765 - val_acc: 0.9348
# Epoch 3/35
# 57s - loss: 0.4205 - acc: 0.8844 - val_loss: 0.3218 - val_acc: 0.9261
# Epoch 4/35
# 57s - loss: 0.3893 - acc: 0.8959 - val_loss: 0.3475 - val_acc: 0.9087
# Epoch 5/35
# 58s - loss: 0.3753 - acc: 0.8968 - val_loss: 0.4129 - val_acc: 0.8957
# Epoch 6/35
# 58s - loss: 0.3372 - acc: 0.9090 - val_loss: 0.3968 - val_acc: 0.9087
# ('Score log_loss: ', 0.41553747794107698)
# Start KFold number 3 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 58s - loss: 0.3398 - acc: 0.9078 - val_loss: 0.2038 - val_acc: 0.9261
# Epoch 2/35
# 57s - loss: 0.3230 - acc: 0.9170 - val_loss: 0.2413 - val_acc: 0.9217
# Epoch 3/35
# 58s - loss: 0.3022 - acc: 0.9200 - val_loss: 0.2384 - val_acc: 0.9391
# Epoch 4/35
# 58s - loss: 0.3054 - acc: 0.9177 - val_loss: 0.2807 - val_acc: 0.9087
# Epoch 5/35
# 58s - loss: 0.2819 - acc: 0.9262 - val_loss: 0.2872 - val_acc: 0.9261
# ('Score log_loss: ', 0.28715785827943952)
# Start KFold number 4 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 61s - loss: 0.2994 - acc: 0.9230 - val_loss: 0.0872 - val_acc: 0.9739
# Epoch 2/35
# 61s - loss: 0.2927 - acc: 0.9255 - val_loss: 0.1096 - val_acc: 0.9565
# Epoch 3/35
# 61s - loss: 0.2674 - acc: 0.9275 - val_loss: 0.1320 - val_acc: 0.9609
# Epoch 4/35
# 57s - loss: 0.2680 - acc: 0.9317 - val_loss: 0.1509 - val_acc: 0.9522
# Epoch 5/35
# 58s - loss: 0.2516 - acc: 0.9392 - val_loss: 0.1834 - val_acc: 0.9565
# ('Score log_loss: ', 0.1834061620628504)
# Start KFold number 5 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 58s - loss: 0.2601 - acc: 0.9278 - val_loss: 0.1337 - val_acc: 0.9348
# Epoch 2/35
# 58s - loss: 0.2486 - acc: 0.9312 - val_loss: 0.2086 - val_acc: 0.9435
# Epoch 3/35
# 58s - loss: 0.2342 - acc: 0.9399 - val_loss: 0.2636 - val_acc: 0.9261
# Epoch 4/35
# 58s - loss: 0.2357 - acc: 0.9422 - val_loss: 0.2914 - val_acc: 0.9261
# Epoch 5/35
# 59s - loss: 0.2401 - acc: 0.9395 - val_loss: 0.2942 - val_acc: 0.9261
# ('Score log_loss: ', 0.29419535626932047)
# Start KFold number 6 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 58s - loss: 0.2473 - acc: 0.9367 - val_loss: 0.1183 - val_acc: 0.9609
# Epoch 2/35
# 58s - loss: 0.2316 - acc: 0.9434 - val_loss: 0.1165 - val_acc: 0.9478
# Epoch 3/35
# 59s - loss: 0.2330 - acc: 0.9376 - val_loss: 0.1303 - val_acc: 0.9522
# Epoch 4/35
# 59s - loss: 0.2299 - acc: 0.9436 - val_loss: 0.1491 - val_acc: 0.9522
# Epoch 5/35
# 58s - loss: 0.2303 - acc: 0.9445 - val_loss: 0.1966 - val_acc: 0.9435
# Epoch 6/35
# 59s - loss: 0.2146 - acc: 0.9457 - val_loss: 0.1944 - val_acc: 0.9435
# ('Score log_loss: ', 0.19441115571801423)
# Start KFold number 7 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 59s - loss: 0.2238 - acc: 0.9420 - val_loss: 0.0868 - val_acc: 0.9696
# Epoch 2/35
# 59s - loss: 0.2165 - acc: 0.9397 - val_loss: 0.1244 - val_acc: 0.9696
# Epoch 3/35
# 58s - loss: 0.2120 - acc: 0.9429 - val_loss: 0.1269 - val_acc: 0.9609
# Epoch 4/35
# 60s - loss: 0.2101 - acc: 0.9457 - val_loss: 0.1670 - val_acc: 0.9565
# Epoch 5/35
# 58s - loss: 0.2154 - acc: 0.9445 - val_loss: 0.1598 - val_acc: 0.9565
# ('Score log_loss: ', 0.15975720921792455)
# Start KFold number 8 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 58s - loss: 0.2119 - acc: 0.9484 - val_loss: 0.1295 - val_acc: 0.9609
# Epoch 2/35
# 58s - loss: 0.2097 - acc: 0.9427 - val_loss: 0.1889 - val_acc: 0.9391
# Epoch 3/35
# 59s - loss: 0.2076 - acc: 0.9452 - val_loss: 0.1641 - val_acc: 0.9478
# Epoch 4/35
# 58s - loss: 0.2040 - acc: 0.9438 - val_loss: 0.2394 - val_acc: 0.9435
# Epoch 5/35
# 59s - loss: 0.1964 - acc: 0.9482 - val_loss: 0.2180 - val_acc: 0.9435
# ('Score log_loss: ', 0.21802656014973906)
# Start KFold number 9 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 59s - loss: 0.2020 - acc: 0.9500 - val_loss: 0.1284 - val_acc: 0.9609
# Epoch 2/35
# 59s - loss: 0.2003 - acc: 0.9475 - val_loss: 0.1231 - val_acc: 0.9478
# Epoch 3/35
# 59s - loss: 0.1912 - acc: 0.9505 - val_loss: 0.1508 - val_acc: 0.9478
# Epoch 4/35
# 59s - loss: 0.1889 - acc: 0.9498 - val_loss: 0.1713 - val_acc: 0.9435
# Epoch 5/35
# 59s - loss: 0.1845 - acc: 0.9477 - val_loss: 0.1895 - val_acc: 0.9435
# Epoch 6/35
# 59s - loss: 0.1861 - acc: 0.9505 - val_loss: 0.1975 - val_acc: 0.9435
# ('Score log_loss: ', 0.19751931507721576)
# Start KFold number 10 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 59s - loss: 0.1892 - acc: 0.9498 - val_loss: 0.1268 - val_acc: 0.9348
# Epoch 2/35
# 59s - loss: 0.1940 - acc: 0.9479 - val_loss: 0.1960 - val_acc: 0.9217
# Epoch 3/35
# 59s - loss: 0.1866 - acc: 0.9489 - val_loss: 0.1822 - val_acc: 0.9391
# Epoch 4/35
# 60s - loss: 0.1778 - acc: 0.9512 - val_loss: 0.2073 - val_acc: 0.9304
# Epoch 5/35
# 59s - loss: 0.1783 - acc: 0.9496 - val_loss: 0.2787 - val_acc: 0.9130
# ('Score log_loss: ', 0.27865127875109691)
# Start KFold number 11 from 20
# ('Split train: ', 4361, 4361)
# ('Split valid: ', 230, 230)
# Train on 4361 samples, validate on 230 samples
# Epoch 1/35
# 60s - loss: 0.1835 - acc: 0.9532 - val_loss: 0.1379 - val_acc: 0.9522
# Epoch 2/35
# 60s - loss: 0.1792 - acc: 0.9498 - val_loss: 0.2081 - val_acc: 0.9435
# Epoch 3/35
# 61s - loss: 0.1778 - acc: 0.9523 - val_loss: 0.2397 - val_acc: 0.9348
# Epoch 4/35
# 63s - loss: 0.1853 - acc: 0.9521 - val_loss: 0.2595 - val_acc: 0.9304
# Epoch 5/35
# 60s - loss: 0.1850 - acc: 0.9537 - val_loss: 0.2596 - val_acc: 0.9348
# ('Score log_loss: ', 0.25964861625003532)
# Start KFold number 12 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 59s - loss: 0.1788 - acc: 0.9523 - val_loss: 0.0893 - val_acc: 0.9607
# Epoch 2/35
# 60s - loss: 0.1824 - acc: 0.9496 - val_loss: 0.1211 - val_acc: 0.9476
# Epoch 3/35
# 59s - loss: 0.1811 - acc: 0.9496 - val_loss: 0.1481 - val_acc: 0.9432
# Epoch 4/35
# 60s - loss: 0.1862 - acc: 0.9498 - val_loss: 0.1965 - val_acc: 0.9432
# Epoch 5/35
# 59s - loss: 0.1805 - acc: 0.9505 - val_loss: 0.1856 - val_acc: 0.9432
# ('Score log_loss: ', 0.1855558696521861)
# Start KFold number 13 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 59s - loss: 0.1926 - acc: 0.9535 - val_loss: 0.1118 - val_acc: 0.9476
# Epoch 2/35
# 59s - loss: 0.1837 - acc: 0.9544 - val_loss: 0.1554 - val_acc: 0.9301
# Epoch 3/35
# 60s - loss: 0.1739 - acc: 0.9537 - val_loss: 0.1748 - val_acc: 0.9258
# Epoch 4/35
# 60s - loss: 0.1740 - acc: 0.9535 - val_loss: 0.1963 - val_acc: 0.9301
# Epoch 5/35
# 65s - loss: 0.1800 - acc: 0.9496 - val_loss: 0.2080 - val_acc: 0.9345
# ('Score log_loss: ', 0.20803677548233254)
# Start KFold number 14 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 60s - loss: 0.1762 - acc: 0.9535 - val_loss: 0.1204 - val_acc: 0.9389
# Epoch 2/35
# 62s - loss: 0.1586 - acc: 0.9594 - val_loss: 0.1715 - val_acc: 0.9345
# Epoch 3/35
# 60s - loss: 0.1692 - acc: 0.9539 - val_loss: 0.2210 - val_acc: 0.9345
# Epoch 4/35
# 60s - loss: 0.1678 - acc: 0.9532 - val_loss: 0.2072 - val_acc: 0.9301
# Epoch 5/35
# 60s - loss: 0.1648 - acc: 0.9571 - val_loss: 0.2695 - val_acc: 0.9301
# ('Score log_loss: ', 0.26949828735488179)
# Start KFold number 15 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 60s - loss: 0.1793 - acc: 0.9519 - val_loss: 0.1581 - val_acc: 0.9520
# Epoch 2/35
# 60s - loss: 0.1582 - acc: 0.9555 - val_loss: 0.1238 - val_acc: 0.9651
# Epoch 3/35
# 60s - loss: 0.1719 - acc: 0.9503 - val_loss: 0.1543 - val_acc: 0.9563
# Epoch 4/35
# 60s - loss: 0.1784 - acc: 0.9514 - val_loss: 0.1822 - val_acc: 0.9563
# Epoch 5/35
# 64s - loss: 0.1688 - acc: 0.9509 - val_loss: 0.2140 - val_acc: 0.9563
# Epoch 6/35
# 60s - loss: 0.1643 - acc: 0.9516 - val_loss: 0.2309 - val_acc: 0.9607
# ('Score log_loss: ', 0.2309364495767906)
# Start KFold number 16 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 60s - loss: 0.1688 - acc: 0.9541 - val_loss: 0.1380 - val_acc: 0.9389
# Epoch 2/35
# 60s - loss: 0.1551 - acc: 0.9553 - val_loss: 0.1979 - val_acc: 0.9258
# Epoch 3/35
# 60s - loss: 0.1757 - acc: 0.9523 - val_loss: 0.2113 - val_acc: 0.9301
# Epoch 4/35
# 59s - loss: 0.1586 - acc: 0.9574 - val_loss: 0.2767 - val_acc: 0.9127
# Epoch 5/35
# 59s - loss: 0.1623 - acc: 0.9530 - val_loss: 0.2822 - val_acc: 0.9170
# ('Score log_loss: ', 0.28221445026343328)
# Start KFold number 17 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 60s - loss: 0.1643 - acc: 0.9498 - val_loss: 0.0893 - val_acc: 0.9607
# Epoch 2/35
# 60s - loss: 0.1669 - acc: 0.9514 - val_loss: 0.1301 - val_acc: 0.9607
# Epoch 3/35
# 60s - loss: 0.1619 - acc: 0.9544 - val_loss: 0.1271 - val_acc: 0.9563
# Epoch 4/35
# 59s - loss: 0.1494 - acc: 0.9560 - val_loss: 0.1537 - val_acc: 0.9520
# Epoch 5/35
# 60s - loss: 0.1613 - acc: 0.9548 - val_loss: 0.1505 - val_acc: 0.9563
# ('Score log_loss: ', 0.15048235215094236)
# Start KFold number 18 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 59s - loss: 0.1726 - acc: 0.9539 - val_loss: 0.0835 - val_acc: 0.9607
# Epoch 2/35
# 60s - loss: 0.1662 - acc: 0.9516 - val_loss: 0.1209 - val_acc: 0.9520
# Epoch 3/35
# 61s - loss: 0.1571 - acc: 0.9528 - val_loss: 0.1358 - val_acc: 0.9476
# Epoch 4/35
# 60s - loss: 0.1652 - acc: 0.9528 - val_loss: 0.1791 - val_acc: 0.9432
# Epoch 5/35
# 60s - loss: 0.1574 - acc: 0.9544 - val_loss: 0.2212 - val_acc: 0.9432
# ('Score log_loss: ', 0.22123870878688434)
# Start KFold number 19 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 60s - loss: 0.1663 - acc: 0.9523 - val_loss: 0.0913 - val_acc: 0.9563
# Epoch 2/35
# 60s - loss: 0.1594 - acc: 0.9592 - val_loss: 0.1232 - val_acc: 0.9345
# Epoch 3/35
# 60s - loss: 0.1619 - acc: 0.9548 - val_loss: 0.1302 - val_acc: 0.9345
# Epoch 4/35
# 60s - loss: 0.1464 - acc: 0.9569 - val_loss: 0.1634 - val_acc: 0.9345
# Epoch 5/35
# 60s - loss: 0.1617 - acc: 0.9562 - val_loss: 0.2099 - val_acc: 0.9345
# ('Score log_loss: ', 0.20992598672350668)
# Start KFold number 20 from 20
# ('Split train: ', 4362, 4362)
# ('Split valid: ', 229, 229)
# Train on 4362 samples, validate on 229 samples
# Epoch 1/35
# 60s - loss: 0.1611 - acc: 0.9548 - val_loss: 0.1026 - val_acc: 0.9520
# Epoch 2/35
# 60s - loss: 0.1633 - acc: 0.9569 - val_loss: 0.1129 - val_acc: 0.9432
# Epoch 3/35
# 61s - loss: 0.1667 - acc: 0.9571 - val_loss: 0.1490 - val_acc: 0.9389
# Epoch 4/35
# 60s - loss: 0.1646 - acc: 0.9546 - val_loss: 0.1384 - val_acc: 0.9476
# Epoch 5/35
# 60s - loss: 0.1374 - acc: 0.9606 - val_loss: 0.1641 - val_acc: 0.9389
# ('Score log_loss: ', 0.16413297704157534)

# %%
score = sum_score/len(Xtrall)
print("Log_loss train independent avg: ", score)

info_string = 'loss_' + str(score) + '_folds_' + str(10) + '_ep_' + str(nb_epoch)
# Out:
# ('Log_loss train independent avg: ', 0.29019959034381443)

# %%
batch_size = 32
num_fold = 0
yfull_test = []
test_id = []
nfolds = len(models)

for i in range(nfolds):
    model = models[i]
    num_fold += 1
    print('Start KFold number {} from {}'.format(num_fold, nfolds))
    test_prediction = model.predict(X_test, batch_size=batch_size, verbose=2)
    yfull_test.append(test_prediction)
# Out:
# Start KFold number 1 from 20
# Start KFold number 2 from 20
# Start KFold number 3 from 20
# Start KFold number 4 from 20
# Start KFold number 5 from 20
# Start KFold number 6 from 20
# Start KFold number 7 from 20
# Start KFold number 8 from 20
# Start KFold number 9 from 20
# Start KFold number 10 from 20
# Start KFold number 11 from 20
# Start KFold number 12 from 20
# Start KFold number 13 from 20
# Start KFold number 14 from 20
# Start KFold number 15 from 20
# Start KFold number 16 from 20
# Start KFold number 17 from 20
# Start KFold number 18 from 20
# Start KFold number 19 from 20
# Start KFold number 20 from 20

# %%
a = np.array(yfull_test[0])
for i in range(1, nfolds):
    a += np.array(yfull_test[i])
a /= nfolds
test_res = a.tolist()

# %%
info_string = 'loss_' + info_string \
                + '_folds_' + str(nfolds)

# %%
params = {"0":"Automobile","1":"Comics_and_Cartoons","2":"Famous_Personalities","3":"Festivals_and_Occasions",
              "4":"Graffiti_and_Illustrations","5":"Movies_and_TV_shows","6":"Music","7":"Nature","8":"No_Theme",
              "9":"Patterns_and_Ethnic","10":"Signs_and_Symbols","11":"Spiritual","12":"Sports","13":"Superheroes",
              "14":"Typography","15":"Vintage"}
    
y = np.array([params[str(i)] for i in np.argmax(test_res, axis=1)])

# %%
result1 = pd.DataFrame(X_test_id, columns=['id'])
result1.loc[:, 'Mobile_Theme'] = pd.Series(y, index=result1.index)
now = datetime.datetime.now()
sub_file = 'submission_keras_v4' +'_'+info_string+  '_' + str(now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
result1.to_csv(sub_file, index=False)
