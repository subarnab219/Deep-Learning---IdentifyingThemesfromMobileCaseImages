# %%
import numpy as np
np.random.seed(2016)

import os
import glob
import cv2
import datetime
import pandas as pd
import time
import warnings
# %matplotlib inline 
warnings.filterwarnings("ignore")

from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
from keras.models import Sequential
from keras import optimizers

import hashlib

# %%
hashes = {}
folders = ['Automobile',
           'Comics_and_Cartoons',
           'Famous_Personalities',
           'Festivals_and_Occasions',
           'Graffiti_and_Illustrations',
           'Movies_and_TV_shows',
           'Music',
           'Nature',
           'No_Theme',
           'Patterns_and_Ethnic',
           'Signs_and_Symbols',
           'Spiritual',
           'Sports',
           'Superheroes',
           'Typography',
           'Vintage'
          ]
for fld in folders:
    index = folders.index(fld)
    print('Load folder {} (Index: {})'.format(fld, index))
    path = os.path.join('D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train', fld, '*.jpg')
    files = glob.glob(path)
    for i in range(len(files)):
        
        h = hashlib.md5(open(files[i],'rb').read()).hexdigest()
        if h in hashes:
            hashes[h].append(files[i])
        else:
            hashes[h] = [files[i]]
print('computing md5 of training data:' + str(len(hashes)))
print('Identical files with different labels:')
for k,v in hashes.items():
    if len(v) > 1:
        if v[0].split('\\')[6] != v[1].split('\\')[6]:
            print "removing:" + v[1]
            os.remove(v[1])
# Out:
# Load folder Automobile (Index: 0)
# Load folder Comics_and_Cartoons (Index: 1)
# Load folder Famous_Personalities (Index: 2)
# Load folder Festivals_and_Occasions (Index: 3)
# Load folder Graffiti_and_Illustrations (Index: 4)
# Load folder Movies_and_TV_shows (Index: 5)
# Load folder Music (Index: 6)
# Load folder Nature (Index: 7)
# Load folder No_Theme (Index: 8)
# Load folder Patterns_and_Ethnic (Index: 9)
# Load folder Signs_and_Symbols (Index: 10)
# Load folder Spiritual (Index: 11)
# Load folder Sports (Index: 12)
# Load folder Superheroes (Index: 13)
# Load folder Typography (Index: 14)
# Load folder Vintage (Index: 15)
# computing md5 of training data:4154
# Identical files with different labels:
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1731.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Spiritual\Img1773.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Vintage\Img5583.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Superheroes\Img5811.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img5835.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1440.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1436.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10360.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1635.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1196.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1627.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img128.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Vintage\Img7791.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1541.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1556.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1613.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Movies_and_TV_shows\Img5935.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1807.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img391.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img3763.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1624.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1564.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img983.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img419.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1562.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img2356.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img272.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1584.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1165.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1530.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img5592.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1683.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Superheroes\Img7602.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Famous_Personalities\Img5492.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1532.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1606.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1677.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1664.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1805.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img4228.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img4601.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Movies_and_TV_shows\Img396.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1551.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10798.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1589.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Movies_and_TV_shows\Img5598.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img696.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1199.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img276.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img3766.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img513.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1733.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1512.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1160.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img200.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img5901.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img4616.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img3844.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1712.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10823.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10250.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10367.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Movies_and_TV_shows\Img5539.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Spiritual\Img1580.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1577.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img4141.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img178.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img5410.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Movies_and_TV_shows\Img1814.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1540.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img5807.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1493.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1618.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1336.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1098.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Vintage\Img5575.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1634.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img911.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Spiritual\Img5950.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10770.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Movies_and_TV_shows\Img5529.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1213.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1559.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1590.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img4196.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img540.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1674.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img5108.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1439.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1527.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1804.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1603.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img5525.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Vintage\Img5576.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1472.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img4587.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1605.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1813.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img1509.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Vintage\Img915.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1614.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img5947.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1799.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Vintage\Img1144.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Spiritual\Img1610.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1699.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img5413.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1741.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Sports\Img5786.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Superheroes\Img5606.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1604.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img5103.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10332.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1687.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1594.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1478.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img888.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img4705.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1419.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1697.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img1782.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1802.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Superheroes\Img7664.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img4573.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Signs_and_Symbols\Img1523.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Superheroes\Img3947.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img5349.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1727.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Nature\Img5868.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Typography\Img1737.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Graffiti_and_Illustrations\Img10614.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Sports\Img5794.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Superheroes\Img7651.jpg
# removing:D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train\Patterns_and_Ethnic\Img4946.jpg

# %%
def get_im_cv2(path):
    img = cv2.imread(path)
    height, width, channels = img.shape
    img = cv2.resize(img, (64, 64))
    return img

# %%
def load_train():
    X_train = []
    X_train_id = []
    y_train = []
    start_time = time.time()
    print('Read train images')
    folders = ['Automobile',
               'Comics_and_Cartoons',
               'Famous_Personalities',
               'Festivals_and_Occasions',
               'Graffiti_and_Illustrations',
               'Movies_and_TV_shows',
               'Music',
               'Nature',
               'No_Theme',
               'Patterns_and_Ethnic',
               'Signs_and_Symbols',
               'Spiritual',
               'Sports',
               'Superheroes',
               'Typography',
               'Vintage'
              ]
    for fld in folders:
        index = folders.index(fld)
        print('Load folder {} (Index: {})'.format(fld, index))
        path = os.path.join('D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Train', fld, '*.jpg')
        files = glob.glob(path)
        for i in range(len(files)):
            flbase = os.path.basename(files[i])
            img = get_im_cv2(files[i])
            X_train.append(img)
            X_train_id.append(flbase)
            y_train.append(index) 
    print('Read train data time: {} seconds'.format(round(time.time() - start_time, 2)))
    return X_train, y_train, X_train_id

# %%
def load_test():
    path = os.path.join('D:\Misc\CrowdAnalytix\Identifying Themes from Mobile Case Images\Data Raw\Test', '*.jpg')
    files = sorted(glob.glob(path))

    X_test = []
    X_test_id = []
    for fl in files:
        flbase = os.path.basename(fl)
        img = get_im_cv2(fl)
        X_test.append(img)
        X_test_id.append(flbase)

    return X_test, X_test_id

# %%
Xtrall, Ytrall, Itrall = load_train()
X_test, X_test_id = load_test()
# Out:
# Read train images
# Load folder Automobile (Index: 0)
# Load folder Comics_and_Cartoons (Index: 1)
# Load folder Famous_Personalities (Index: 2)
# Load folder Festivals_and_Occasions (Index: 3)
# Load folder Graffiti_and_Illustrations (Index: 4)
# Load folder Movies_and_TV_shows (Index: 5)
# Load folder Music (Index: 6)
# Load folder Nature (Index: 7)
# Load folder No_Theme (Index: 8)
# Load folder Patterns_and_Ethnic (Index: 9)
# Load folder Signs_and_Symbols (Index: 10)
# Load folder Spiritual (Index: 11)
# Load folder Sports (Index: 12)
# Load folder Superheroes (Index: 13)
# Load folder Typography (Index: 14)
# Load folder Vintage (Index: 15)
# Read train data time: 155.73 seconds

# %%
# flatten out all images to be one-dimensional
Xtrall = np.array(Xtrall, dtype=np.uint8)
Ytrall = np.array(Ytrall, dtype=np.uint8)

Xtrall = Xtrall.astype('float32')
Xtrall = Xtrall / 255
Xtrall = Xtrall.transpose((0, 3, 1, 2))

# msk = np.random.rand(len(Xtrall)) < 0.8
# Xval = Xtrall[~msk]
# Yval = Ytrall[~msk]
# Ytr = Ytrall[msk]
# Xtr = Xtrall[msk]

X_test = np.array(X_test, dtype=np.uint8)

X_test = X_test.astype('float32')
X_test = X_test / 255
X_test = X_test.transpose((0, 3, 1, 2))

Ytrall = np_utils.to_categorical(Ytrall, 16)

# %%
batch_size=64
nb_classes=len(Ytrall)
nb_epoch=30
nb_filters=64
nb_pool=1
nb_conv=3

# %%
model= Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=Xtrall.shape[1:]))
model.add(Convolution2D(nb_filters,nb_conv,nb_conv, subsample=(1, 1),activation='relu'))
model.add(Activation('relu'))
model.add(Convolution2D(nb_filters/2,nb_conv,nb_conv, subsample=(1, 1),activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64))
model.add(Dropout(0.5))
model.add(Dense(32))
model.add(Dropout(0.5))
model.add(Dense(16))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',optimizer="adadelta",metrics=['accuracy'])

# %%
nfolds = 5
yfull_train = dict()
kf = KFold(len(Itrall), n_folds=nfolds, shuffle=True, random_state=51)
num_fold = 0
sum_score = 0
models = []

for mtr,mval in kf:
    Xtr = Xtrall[mtr]
    Ytr = Ytrall[mtr]
    Xval = Xtrall[mval]
    Yval = Ytrall[mval]
    
    num_fold += 1
    
    print('Start KFold number {} from {}'.format(num_fold, nfolds))
    print('Split train: ', len(Xtr), len(Ytr))
    print('Split valid: ', len(Xval), len(Yval))
    
    callbacks = [
            EarlyStopping(monitor='val_loss', patience=3, verbose=0),
        ]
    model.fit(Xtr,Ytr, batch_size=batch_size, nb_epoch=nb_epoch,
              shuffle=True, verbose=2, validation_data=(Xval, Yval),
              callbacks=callbacks)
    predictions_valid = model.predict(Xval.astype('float32'), batch_size=batch_size, verbose=2)
    score = log_loss(Yval, predictions_valid)
    print('Score log_loss: ', score)
    sum_score += score*len(mval)
    
    # Store valid predictions
    for i in range(len(mval)):
        yfull_train[mval[i]] = predictions_valid[i]

    models.append(model)
# Out:
# Start KFold number 1 from 5
# ('Split train: ', 3565, 3565)
# ('Split valid: ', 892, 892)
# Train on 3565 samples, validate on 892 samples
# Epoch 1/30
# 89s - loss: 2.3355 - acc: 0.3431 - val_loss: 1.7475 - val_acc: 0.5291
# Epoch 2/30
# 89s - loss: 1.8279 - acc: 0.4850 - val_loss: 1.6257 - val_acc: 0.5617
# Epoch 3/30
# 88s - loss: 1.6673 - acc: 0.5338 - val_loss: 1.5607 - val_acc: 0.5818
# Epoch 4/30
# 88s - loss: 1.5068 - acc: 0.5697 - val_loss: 1.4907 - val_acc: 0.5964
# Epoch 5/30
# 88s - loss: 1.3427 - acc: 0.6196 - val_loss: 1.4354 - val_acc: 0.6166
# Epoch 6/30
# 87s - loss: 1.2115 - acc: 0.6522 - val_loss: 1.4036 - val_acc: 0.6267
# Epoch 7/30
# 88s - loss: 1.0598 - acc: 0.6903 - val_loss: 1.4139 - val_acc: 0.6357
# Epoch 8/30
# 88s - loss: 0.9364 - acc: 0.7243 - val_loss: 1.3803 - val_acc: 0.6267
# Epoch 9/30
# 88s - loss: 0.8628 - acc: 0.7509 - val_loss: 1.3484 - val_acc: 0.6446
# Epoch 10/30
# 91s - loss: 0.7296 - acc: 0.7947 - val_loss: 1.3722 - val_acc: 0.6446
# Epoch 11/30
# 93s - loss: 0.6661 - acc: 0.8048 - val_loss: 1.4079 - val_acc: 0.6334
# Epoch 12/30
# 89s - loss: 0.6192 - acc: 0.8180 - val_loss: 1.4047 - val_acc: 0.6547
# Epoch 13/30
# 87s - loss: 0.5321 - acc: 0.8463 - val_loss: 1.4569 - val_acc: 0.6413
# ('Score log_loss: ', 1.460976689595787)
# Start KFold number 2 from 5
# ('Split train: ', 3565, 3565)
# ('Split valid: ', 892, 892)
# Train on 3565 samples, validate on 892 samples
# Epoch 1/30
# 89s - loss: 0.8056 - acc: 0.7877 - val_loss: 0.2614 - val_acc: 0.9372
# Epoch 2/30
# 91s - loss: 0.7241 - acc: 0.8011 - val_loss: 0.3098 - val_acc: 0.9327
# Epoch 3/30
# 88s - loss: 0.6072 - acc: 0.8359 - val_loss: 0.2499 - val_acc: 0.9484
# Epoch 4/30
# 88s - loss: 0.5484 - acc: 0.8485 - val_loss: 0.3276 - val_acc: 0.9103
# Epoch 5/30
# 90s - loss: 0.4701 - acc: 0.8651 - val_loss: 0.2876 - val_acc: 0.9114
# Epoch 6/30
# 90s - loss: 0.4603 - acc: 0.8735 - val_loss: 0.3209 - val_acc: 0.9103
# Epoch 7/30
# 89s - loss: 0.4079 - acc: 0.8842 - val_loss: 0.2620 - val_acc: 0.9238
# ('Score log_loss: ', 0.26736021109868591)
# Start KFold number 3 from 5
# ('Split train: ', 3566, 3566)
# ('Split valid: ', 891, 891)
# Train on 3566 samples, validate on 891 samples
# Epoch 1/30
# 89s - loss: 0.4358 - acc: 0.8749 - val_loss: 0.0866 - val_acc: 0.9832
# Epoch 2/30
# 89s - loss: 0.4135 - acc: 0.8856 - val_loss: 0.0956 - val_acc: 0.9854
# Epoch 3/30
# 87s - loss: 0.3883 - acc: 0.8890 - val_loss: 0.1069 - val_acc: 0.9764
# Epoch 4/30
# 88s - loss: 0.3429 - acc: 0.9047 - val_loss: 0.1295 - val_acc: 0.9753
# Epoch 5/30
# 86s - loss: 0.3231 - acc: 0.9033 - val_loss: 0.1482 - val_acc: 0.9675
# ('Score log_loss: ', 0.14821609124391544)
# Start KFold number 4 from 5
# ('Split train: ', 3566, 3566)
# ('Split valid: ', 891, 891)
# Train on 3566 samples, validate on 891 samples
# Epoch 1/30
# 89s - loss: 0.3130 - acc: 0.9105 - val_loss: 0.0563 - val_acc: 0.9865
# Epoch 2/30
# 87s - loss: 0.3129 - acc: 0.9128 - val_loss: 0.0741 - val_acc: 0.9809
# Epoch 3/30
# 90s - loss: 0.3064 - acc: 0.9192 - val_loss: 0.0801 - val_acc: 0.9854
# Epoch 4/30
# 88s - loss: 0.2692 - acc: 0.9279 - val_loss: 0.0879 - val_acc: 0.9809
# Epoch 5/30
# 90s - loss: 0.2461 - acc: 0.9307 - val_loss: 0.1005 - val_acc: 0.9787
# ('Score log_loss: ', 0.10048317331745855)
# Start KFold number 5 from 5
# ('Split train: ', 3566, 3566)
# ('Split valid: ', 891, 891)
# Train on 3566 samples, validate on 891 samples
# Epoch 1/30
# 93s - loss: 0.2642 - acc: 0.9262 - val_loss: 0.0440 - val_acc: 0.9865
# Epoch 2/30
# 89s - loss: 0.2661 - acc: 0.9248 - val_loss: 0.0508 - val_acc: 0.9854
# Epoch 3/30
# 89s - loss: 0.2470 - acc: 0.9316 - val_loss: 0.0562 - val_acc: 0.9854
# Epoch 4/30
# 89s - loss: 0.2203 - acc: 0.9335 - val_loss: 0.0617 - val_acc: 0.9787
# Epoch 5/30
# 90s - loss: 0.2146 - acc: 0.9375 - val_loss: 0.0682 - val_acc: 0.9787
# ('Score log_loss: ', 0.068156520227126038)

# %%
score = sum_score/len(Xtrall)
print("Log_loss train independent avg: ", score)

info_string = 'loss_' + str(score) + '_folds_' + str(10) + '_ep_' + str(nb_epoch)
# Out:
# ('Log_loss train independent avg: ', 0.40924276860355024)

# %%
batch_size = 32
num_fold = 0
yfull_test = []
test_id = []
nfolds = len(models)

for i in range(nfolds):
    model = models[i]
    num_fold += 1
    print('Start KFold number {} from {}'.format(num_fold, nfolds))
    test_prediction = model.predict(X_test, batch_size=batch_size, verbose=2)
    yfull_test.append(test_prediction)
# Out:
# Start KFold number 1 from 5
# Start KFold number 2 from 5
# Start KFold number 3 from 5
# Start KFold number 4 from 5
# Start KFold number 5 from 5

# %%
a = np.array(yfull_test[0])
for i in range(1, nfolds):
    a += np.array(yfull_test[i])
a /= nfolds
test_res = a.tolist()

# %%
info_string = 'loss_' + info_string \
                + '_folds_' + str(nfolds)

# %%
params = {"0":"Automobile","1":"Comics_and_Cartoons","2":"Famous_Personalities","3":"Festivals_and_Occasions",
              "4":"Graffiti_and_Illustrations","5":"Movies_and_TV_shows","6":"Music","7":"Nature","8":"No_Theme",
              "9":"Patterns_and_Ethnic","10":"Signs_and_Symbols","11":"Spiritual","12":"Sports","13":"Superheroes",
              "14":"Typography","15":"Vintage"}
    
y = np.array([params[str(i)] for i in np.argmax(test_res, axis=1)])

# %%
result1 = pd.DataFrame(X_test_id, columns=['id'])
result1.loc[:, 'Mobile_Theme'] = pd.Series(y, index=result1.index)
now = datetime.datetime.now()
sub_file = 'submission_keras_v4' +'_'+info_string+  '_' + str(now.strftime("%Y-%m-%d-%H-%M")) + '.csv'
result1.to_csv(sub_file, index=False)
